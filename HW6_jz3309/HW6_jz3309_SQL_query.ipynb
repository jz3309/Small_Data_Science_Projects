# %% [markdown]
# # SQL CARTO QUERY FUNCTION
# # written for PUI2016_Python2

# %% [markdown]
# ##### This notebook is set up to link as a default to the fb55 account.  To turn in the homework use the citibike dataset - check that you are able to read in about 40k rows

# %%
SQL_SOURCE = 'https://fb55.carto.com/api/v2/sql?q='

import urllib2
import urllib
import StringIO
import ast
import pandas as pd

try:
    from urllib.request import urlopen
except ImportError:
    from urllib2 import urlopen
try:
    from urllib.error import HTTPError
except ImportError:
    from urllib2 import HTTPError
try:
    from urllib.parse import urlencode
except ImportError:
    from urllib import urlencode
import io


def queryCartoDB(query, format='CSV', source=SQL_SOURCE):
    '''queries carto datasets from a given carto account
    Arguments: 
    query - string: a valid sql query string
    format - outlut format  OPTIONAL (default CSV)
    source - a valid sql api endpoint OPTIONAL (default carto fb55 account)
    Returns:
    the return of the sql query AS A STRING
    NOTES:
    designed for the carto API, tested only with CSV return format'''
    
    data = urllib.urlencode({'format': format, 'q': query})
    try:
        response = urllib2.urlopen(source, data)
    except urllib2.HTTPError, e:
        raise ValueError('\n'.join(ast.literal_eval(e.readline())['error']))
    except Exception:
        raise
    return response.read()

# %%
test = '''
SELECT *
FROM citibike
'''

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(test)), sep=',')
# Out:
#        the_geom        start_station_name  the_geom_webmercator  field_1  \
# 0           NaN        E 20 St & Park Ave                   NaN      175
# 1           NaN          W 43 St & 10 Ave                   NaN     1159
# 2           NaN         E 6 St & Avenue B                   NaN     2827
# 3           NaN           E 12 St & 3 Ave                   NaN     4961
# 4           NaN           W 41 St & 8 Ave                   NaN     6156
# 5           NaN           5 Ave & E 29 St                   NaN     7433
# 6           NaN      Allen St & Hester St                   NaN     7779
# 7           NaN           E 39 St & 3 Ave                   NaN     8327
# 8           NaN          10 Ave & W 28 St                   NaN     9435
# 9           NaN            E 2 St & 2 Ave                   NaN    10472
# 10          NaN           1 Ave & E 44 St                   NaN    10931
# 11          NaN           W 45 St & 6 Ave                   NaN    11361
# ...

# %%
test = '''
SELECT * FROM citibike
WHERE tripduration<10800
ORDER BY start_station_id
LIMIT 10
'''

pd.read_csv(io.BytesIO(queryCartoDB(test)), sep=',')
# Out:
#    the_geom start_station_name  the_geom_webmercator  field_1  \
# 0       NaN   W 52 St & 11 Ave                   NaN     3370
# 1       NaN   W 52 St & 11 Ave                   NaN     4024
# 2       NaN   W 52 St & 11 Ave                   NaN     2348
# 3       NaN   W 52 St & 11 Ave                   NaN     2051
# 4       NaN   W 52 St & 11 Ave                   NaN      455
# 5       NaN   W 52 St & 11 Ave                   NaN     1597
# 6       NaN   W 52 St & 11 Ave                   NaN     2208
# 7       NaN   W 52 St & 11 Ave                   NaN      718
# 8       NaN   W 52 St & 11 Ave                   NaN     1299
# 9       NaN   W 52 St & 11 Ave                   NaN     5202
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.993929           569  2015-02-01 14:52:00+00
# 1               -73.993929           387  2015-02-01 15:57:00+00
# 2               -73.993929           301  2015-02-01 13:08:00+00
# ...

# %%
test = '''
SELECT DISTINCT start_station_id FROM citibike

'''

pd.read_csv(io.BytesIO(queryCartoDB(test)), sep=',')
# Out:
#      start_station_id  Unnamed: 1
# 0                 120         NaN
# 1                 285         NaN
# 2                 251         NaN
# 3                 195         NaN
# 4                 453         NaN
# 5                 144         NaN
# 6                 266         NaN
# 7                 263         NaN
# 8                 216         NaN
# 9                 328         NaN
# 10                353         NaN
# 11                212         NaN
# 12                383         NaN
# 13                538         NaN
# 14                217         NaN
# 15                300         NaN
# 16                456         NaN
# 17                128         NaN
# 18                223         NaN
# 19                244         NaN
# 20                494         NaN
# 21                403         NaN
# 22                260         NaN
# 23                445         NaN
# 24                411         NaN
# 25                377         NaN
# ...

# %%
test = '''
SELECT COUNT(bikeid) as trips,
       MAX(tripduration) as maxduration,
       MIN(tripduration) as minduration,
       AVG(tripduration) as avgduration 
FROM citibike
'''

pd.read_csv(io.BytesIO(queryCartoDB(test)), sep=',')
# Out:
#    trips  maxduration  minduration  avgduration
# 0  46200        43016           60   675.865823

# %% [markdown]
# # task2

# %%
test = '''
SELECT * FROM citibike
WHERE DATE(starttime)='2015-02-02'
'''

# %%
pd.read_csv(io.BytesIO(queryCartoDB(test)), sep=',')
# Out:
#       the_geom           start_station_name  the_geom_webmercator  field_1  \
# 0          NaN              5 Ave & E 29 St                   NaN     7433
# 1          NaN         Allen St & Hester St                   NaN     7779
# 2          NaN            E 5 St & Avenue C                   NaN       11
# 3          NaN              9 Ave & W 16 St                   NaN      627
# 4          NaN              9 Ave & W 16 St                   NaN      991
# 5          NaN              W 33 St & 7 Ave                   NaN     1037
# 6          NaN              W 27 St & 7 Ave                   NaN     6510
# 7          NaN              E 11 St & 1 Ave                   NaN     6511
# 8          NaN         Peck Slip & Front St                   NaN     6512
# 9          NaN              E 16 St & 5 Ave                   NaN     6513
# 10         NaN              W 41 St & 8 Ave                   NaN     6514
# ...

# %%
test = '''
SELECT AVG(tripduration) FROM citibike
WHERE EXTRACT(DOW FROM starttime) in (0,6)
'''

# %%
pd.read_csv(io.BytesIO(queryCartoDB(test)), sep=',')
# Out:
#           avg  Unnamed: 1
# 0  662.942181         NaN

# %%
test = '''
SELECT AVG(tripduration) FROM citibike
WHERE EXTRACT(DOW FROM starttime) in (1,2,3,4,5)
'''

# %%
pd.read_csv(io.BytesIO(queryCartoDB(test)), sep=',')
# Out:
#           avg  Unnamed: 1
# 0  681.052292         NaN

# %%
test = '''SELECT DISTINCT ON (start_station_id)
start_station_name,start_station_latitude,start_station_longitude FROM citibike


'''

# %%
pd.read_csv(io.BytesIO(queryCartoDB(test)), sep=',')
# Out:
#                   start_station_name  start_station_latitude  \
# 0                   W 52 St & 11 Ave               40.767272
# 1           Franklin St & W Broadway               40.719116
# 2             St James Pl & Pearl St               40.711174
# 3      Atlantic Ave & Fort Greene Pl               40.683826
# 4                    W 17 St & 8 Ave               40.741776
# 5           Park Ave & St Edwards St               40.696089
# 6        Lexington Ave & Classon Ave               40.686768
# 7              Barrow St & Hudson St               40.731724
# 8           MacDougal St & Prince St               40.727103
# 9              E 56 St & Madison Ave               40.761628
# 10         Clinton St & Joralemon St               40.692395
# 11               Nassau St & Navy St               40.698399
# 12              Hudson St & Reade St               40.716250
# 13          Greenwich St & Warren St               40.715422
# ...

# %%
test = '''SELECT COUNT(bikeid),start_station_id FROM citibike
GROUP BY start_station_id



'''

# %%
pd.read_csv(io.BytesIO(queryCartoDB(test)), sep=',')
# Out:
#      count  start_station_id
# 0       17               120
# 1      373               285
# 2      194               251
# 3      137               195
# 4      218               453
# 5        7               144
# 6       38               266
# 7      217               263
# 8       12               216
# 9       73               328
# 10      29               353
# 11     186               212
# 12     142               383
# 13     153               538
# 14      14               217
# 15     161               300
# 16     110               456
# 17     247               128
# 18     179               223
# 19      35               244
# 20     237               494
# 21     151               403
# 22      36               260
# 23     296               445
# 24      86               411
# 25     101               377
# 26      42               427
# 27      22               232
# 28      52               331
# 29      36               416
# ..     ...               ...
# ...

# %%
query = """
SELECT COUNT(*) FROM citibike
WHERE ST_DWithin(CDB_LatLng(start_station_latitude, start_station_longitude)::geography,
                 CDB_LatLng(40.7577, -73.9857)::geography,
                 500)
GROUP BY start_station_id
"""
pd.read_csv(StringIO.StringIO(queryCartoDB(query)), sep=',')
# Out:
#    count  Unnamed: 1
# 0    213         NaN
# 1    251         NaN
# 2    507         NaN
# 3    141         NaN
# 4    112         NaN
# 5    221         NaN
# 6    141         NaN

# %%
test ='''
SELECT * FROM(
    SELECT start_station_id,AVG(tripduration) as averageduration FROM citibike
    WHERE EXTRACT(DOW FROM starttime) in (0,6)
    AND ST_DWithin(CDB_LatLng(start_station_latitude, start_station_longitude)::geography,
                 CDB_LatLng(40.7577, -73.9857)::geography,
                 500)

    GROUP BY start_station_id) as allaverage
    
ORDER BY allaverage.averageduration DESC
LIMIT 1

'''

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(test)), sep=',')
# Out:
#    start_station_id  averageduration
# 0               173      1010.104167

# %% [markdown]
# # extra credit: make the function python 2 and 3 compatible so that it works on the  PUI2016_Python3 kernel
