# %% [markdown]
# # HW4_jz3309_Assignment1

# %%
import pylab as pl
import seaborn as sns
from scipy.optimize import curve_fit, minimize
import numpy as np

    
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # 1. Chi square

# %%
mymean = 200
df = mymean
md = {}

md['chisq'] = np.random.chisquare(df, size=100)

pl.hist(md['chisq'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')
pl.title('Plot of chisquare distribution')
# Out:
# Text(0.5,1,'Plot of chisquare distribution')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Figure1.1: Chi sq distribution: df=200,N=100

# %%
print ("Chisq mean: %.2f, standard deviation: %.2f"%(md['chisq'].mean(), md['chisq'].std()))
# Out:
# Chisq mean: 201.46, standard deviation: 19.75

# %%
chisize = (np.random.rand(100)*2000).astype(int)

# %%
np.random.seed(100)
chins = 100
chi_list=[]
for i in range(chins):
    for j in chisize:
        sample = np.random.chisquare(200, size = j)
        chi_list.append(sample)

# %%
ax = plt.figure(figsize=(6,6)).add_subplot(111)
for i in range(ns):
    ax.plot(chi_list[i].size, chi_list[i].mean(), ".")
ax.plot([0,2000],[200,200],"-")
ax.set_xlabel('Sample Size')
ax.set_ylabel('Sample Mean')
ax.set_title('Scatter plot of the mean(Chi square)',fontsize= 15)
# Out:
# Text(0.5,1,'Scatter plot of the mean(Chi square)')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Figure1.2:   The above plot shows the sample mean against the sample size . When the sample size become larger, the mean of sample size is closer  aprroximately 200. This result relating to the LLN,  the average of the results obtained from a large number of trials(100samples, different sizes) are close to the expected value(my mean is 200), and tend to become closer and stable as more trials are performed.

# %%
sns.distplot([chi_list[i].mean() for i in range(ns)], color= 'r', kde=True)
pl.xlabel('sample mean', fontsize = 10)
pl.ylabel( 'N', fontsize = 10)
pl.title('Histogram of distribution of sample mean (Chi square)', fontsize = 12)
# Out:
# Text(0.5,1,'Histogram of distribution of sample mean (Chi square)')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ###  Figure1.2: The figure shows that the distribution of chi square distribution mean relates to the central limit theorem. The distribution of the average is closely approximated by a Gauss distribution curve where mean is 200.

# %% [markdown]
# ###  I plot a histogram for all the distribution means at last of this notebook.

# %% [markdown]
# # 2. Poisson Distribution

# %%
from scipy import stats

# %%
np.random.randint?

# %%
pns = 100

poisson_list = []
for i in range(pns):
    sample = stats.poisson.rvs(mu=200, loc=0, size = np.random.randint(20,2000))
    poisson_list.append(sample)

# %%
np.array(poisson_list).size
# Out:
# 100

# %%
ax = plt.figure(figsize=(5,5)).add_subplot(111)
for i in range(pns):
    ax.plot(poisson_list[i].size, poisson_list[i].mean(), ".")
ax.plot([0,2000],[200,200],"-")
ax.set_xlabel('Sample Size')
ax.set_ylabel('Sample Mean')
ax.set_title('Scatter plot of the mean of sample size(Poisson)')
# Out:
# Text(0.5,1,'Scatter plot of the mean of sample size(Poisson)')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Figure2.2:   The scatter plot shows the sample mean against the sample size of Poisson distribution . When the sample size become larger, the mean of sample size is closer  aprroximately 200. The result relating to the LLN,  the average of the results obtained from a large number of trials(100samples, different sizes) are close to the expected value(my mean is 200), and tend to become closer and stable as more trials are performed.

# %%
sns.distplot([poisson_list[i].mean() for i in range(ns)], color= 'r', kde=True)
plt.xlabel('Smaple Mean')
plt.ylabel('N')
plt.title('Histogram of 100 sample means(Possion) ')
# Out:
# Text(0.5,1,'Histogram of 100 sample means(Possion) ')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ###  Figure2.2: The figure shows that the distribution of sample mean following Poisson distribution relates to the central limit theorem. The distribution of the average is closely approximated by a Gauss distribution curve where mean is 200.

# %% [markdown]
# # 3.  Binomial

# %%
bns = 100


bin_list = []
for i in range(bns):
    sample = stats.binom.rvs(n=400  ,p = 0.5, size = np.random.randint(20,2000))
    bin_list.append(sample)
    
ax = plt.figure(figsize=(6,6)).add_subplot(111)
for i in range(bns):
    ax.plot(bin_list[i].size, bin_list[i].mean(), ".")
ax.plot([0,2000],[200,200],"-")
ax.set_xlabel('Sample Size')
ax.set_ylabel('Sample Mean')
ax.set_title('Scatter plot of the mean of sample size(Binomial)')
# Out:
# Text(0.5,1,'Scatter plot of the mean of sample size(Binomial)')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Figure3.1 : The scatter plot shows the sample mean against the sample size of Binomial distribution . When the sample size become larger, the mean of sample size is closer aprroximately 200. The result relating to the LLN, the average of the results obtained from a large number of trials(100samples, different sizes) are close to the expected value(my mean is 200), and tend to become closer and stable as more trials are performed.

# %%
sns.distplot([bin_list[i].mean() for i in range(ns)], color= 'r', kde=True)
plt.xlabel('Smaple Mean')
plt.ylabel('N')
plt.title('Histogram of 100 sample means(Binomial) ')
# Out:
# Text(0.5,1,'Histogram of 100 sample means(Binomial) ')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Figure3.2: The figure shows that the distribution of sample mean following Binomial distribution relates to the central limit theorem. The distribution of the average is closely approximated by a Gauss distribution curve where mean is 200.

# %% [markdown]
# # 4. Gauss Distribution (Normal Distribution)

# %%
np.random.randn?

# %%
np.random.seed(99)
ns = 100 #number of sample
gauss_list = []
for i in range(ns):
    sample = np.random.randn(np.random.rand() * 1990 + 10)+200
    gauss_list.append(sample)
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:5: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
ax = plt.figure(figsize=(6,6)).add_subplot(111)
for i in range(ns):
    ax.plot(gauss_list[i].size, gauss_list[i].mean(), ".")
ax.plot([0,2000],[200,200],"-")
ax.set_xlabel('Sample Size')
ax.set_ylabel('Sample Mean')
ax.set_title('Scatter plot of the mean(Gauss)',fontsize= 15)
# Out:
# Text(0.5,1,'Scatter plot of the mean(Gauss)')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Figure4.1: The scatter plot shows the sample mean against the sample size of Gauss distribution . When the sample size become larger, the mean of sample size is closer aprroximately 200. The result relating to the LLN, the average of the results obtained from a large number of trials(100samples, different sizes) are close to the expected value(my mean is 200), and tend to become closer and stable as more trials are performed.

# %%
sns.distplot([gauss_list[i].mean() for i in range(ns)], color= 'r', kde=True)
plt.xlabel('Smaple Mean')
plt.ylabel('N')
plt.title('Histogram of 100 sample means(Norm) ')
# Out:
# Text(0.5,1,'Histogram of 100 sample means(Norm) ')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Figure4.2: The figure shows that the distribution of sample mean following Gaussdistribution relates to the central limit theorem. The distribution of the average is closely approximated by a Gauss distribution curve where mean is 200.

# %% [markdown]
# # 5.Laplace Distribution

# %%
ls = 100

lap_list = []
for i in range(ls):
    sample = np.random.laplace(loc = 200, size = np.random.randint(20,2000))
    lap_list.append(sample)

# %%
ax = plt.figure(figsize=(6,6)).add_subplot(111)
for i in range(ls):
    ax.plot(lap_list[i].size, lap_list[i].mean(), ".")
ax.plot([0,2000],[200,200],"-")
ax.set_xlabel('Sample Size')
ax.set_ylabel('Sample Mean')
ax.set_title('Scatter plot of the mean(Laplace)',fontsize= 15)
# Out:
# Text(0.5,1,'Scatter plot of the mean(Laplace)')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Figure5.1: The scatter plot shows the sample mean against the sample size following Laplace distribution . When the sample size become larger, the mean of sample size is closer aprroximately 200. The result relating to the LLN, the average of the results obtained from a large number of trials(100samples, different sizes) are close to the expected value(mean is  0 ), and tend to become closer and stable as more trials are performed.

# %%
sns.distplot([lap_list[i].mean() for i in range(ls)], color= 'r', kde=True)
plt.xlabel('Smaple Mean')
plt.ylabel('N')
plt.title('Histogram of 100 sample means(Laplace) ')
# Out:
# Text(0.5,1,'Histogram of 100 sample means(Laplace) ')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Figure5.2: The figure shows that the distribution of sample mean following Laplace distribution relates to the central limit theorem. The distribution of the average is closely approximated by a Normal distribution curve where mean is 200.

# %% [markdown]
# # A histogram for all the 5 distribution means.

# %%
plt.hist([chi_list[i].mean() for i in range(ns)],10, color= 'r',alpha = 0.5)
plt.hist([poisson_list[i].mean() for i in range(ns)],10, color= 'b',alpha = 0.5 )
plt.hist([bin_list[i].mean() for i in range(ns)],10,  color= 'y',alpha = 0.5)
plt.hist([gauss_list[i].mean() for i in range(ns)],10,  color= 'g',alpha = 0.7)
plt.hist([lap_list[i].mean() for i in range(ls)],10,  color= 'r',alpha = 0.8)


pl.xlabel('sample mean', fontsize = 10)
pl.ylabel( 'N', fontsize = 10)
pl.title('Histogram of distribution of sample mean ', fontsize = 12)
# Out:
# Text(0.5,1,'Histogram of distribution of sample mean ')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Figure6: The histogram of all  5 distribution means shows that the distribution of sample mean following Laplace distribution relates to the central limit theorem.

# %%
df2=pd.concat(data.iloc[:,i] for i in range(data.shape[1]))
mu = df2.mean()
sigma = df2.std()

# %%
import pandas as pd
a = [chi_list[i].mean() for i in range(ns)]
b = [poisson_list[i].mean() for i in range(ns)]
c = [bin_list[i].mean() for i in range(ns)]
d = [gauss_list[i].mean() for i in range(ns)]
e = [lap_list[i].mean() for i in range(ls)]
data = pd.DataFrame([a+b+c+d+e])
data
# Out:
#           0           1          2           3           4           5    \
# 0  200.421736  200.619998  199.70903  201.182847  199.862366  200.465879
#
#           6           7           8           9       ...             490  \
# 0  200.465595  200.614267  199.633793  199.351431     ...      199.956634
#
#           491         492         493         494         495         496  \
# 0  200.036439  199.962107  200.065281  200.002937  199.980028  199.994375
#
#           497         498         499
# 0  199.776829  200.018554  200.051653
#
# [1 rows x 500 columns]

# %%
sns.distplot(data.iloc[0],color = 'b')
plt.xlabel('Smaple Mean')
plt.ylabel('N')
plt.title('Histogram of 500 sample means ')
# Out:
# Text(0.5,1,'Histogram of 500 sample means ')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Figure7: After fitting a curve to all the means show that the distribution of sample mean relates to the central limit theorem. The distribution of the average is closely approximated by a Normal distribution curve where mean is 200.
